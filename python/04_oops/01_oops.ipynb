# %%
class Car:
    pass

audi = Car()

bmw = Car()

print(type(audi))
print(type(bmw))
# Out:
# <class '__main__.Car'>
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)
# Out:
# <__main__.Car object at 0x000001F1E33F3290>
# <__main__.Car object at 0x000001F1E34C7A10>

# %%
audi.windows = 4 # not a proper way of initializing a objet
print(audi.windows)
# Out:
# 4

# %%
## Instance Variable and Methods
class Dog:
    ## contructor
    def __init__(self, name, age):
        self.name = name
        self.age = age

dog1 = Dog('Rocky', 8)

# %%
print(dog1.name, dog1.age)
# Out:
# Rocky 8

# %%
dog2 = Dog("Lucy", 4)
print(dog2.name)
print(dog2.age)
# Out:
# Lucy
# 4

# %%
# Define a class with instance methods
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def bark(self):
        print(f"{self.name} says woof!")

dog1 = Dog("Buddy", 3)
dog1.bark()
# Out:
# Buddy says woof!

# %%
## Modeling a Bank account

class BankAccount:
    # class varible
    count = 0
    def __init__(self, owner, balance=0):
        self.owner = owner # Instance variable
        self.balance = balance
        BankAccount.count+=1

    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} is deposited. New balance is {self.balance}")

    def withdraw(self, amount):
        if(amount > self.balance):
            print("Insufficient funds!")
        else:
            self.balance -= amount
            print(f"{amount} is withdrawn. New balance is {self.balance}")

    def get_balance(self):
        return self.balance

jon = BankAccount("Jon", 10000)
kay = BankAccount("Kay", 10000)
pay = BankAccount("pay", 10000)

print(jon.get_balance())
jon.withdraw(500)
print(jon.get_balance())
# Out:
# 10000
# 500 is withdrawn. New balance is 9500
# 9500
