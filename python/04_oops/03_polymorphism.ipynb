# %%
### Method overloading

# Base class
class Animal:
    def speak(self):
        return "Sound of the animal"
    
# Derived class 1
class Dog(Animal):
    def speak(self):
        return "Woof!"
    
## Derived class
class Cat(Animal):
    def speak(self):
        return "Meow!"
    

## Function that demonstrates polymorphism
def animal_speak(animal):
    print(animal.speak())
    
dog = Dog()
print(dog.speak())
cat = Cat()
print(cat.speak())

animal_speak(dog)
# Out:
# Woof!
# Meow!
# Woof!

# %%
### Polymorphism with Functions and Methods
## base class
class Shape:
    def area(self):
        return "The area of the figure"

# Derived class 1
class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def area(self):
        return self.width*self.height
    
# Derived class 2

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14*self.radius*self.radius
    

def print_area(shape):
    print(f"area of this shape is {shape.area()}")

rect = Rectangle(4, 5)
circ = Circle(3)

print_area(rect)
print_area(circ)
# Out:
# area of this shape is 20
# area of this shape is 28.259999999999998

# %%
## abstract base class or you can say interfaces

from abc import ABC, abstractmethod

## Define an abstract class
class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass

# Derived class 1

class Car(Vehicle):
    def start_engine(self):
        return "Car engine started"
    
# Derived class 2

class MotorCycle(Vehicle):
    def start_engine(self):
        return "Motor cycle engine started"
    
## create objects of cars and motorcycle

def start_vehicle(vehicle: Vehicle):
    print(vehicle.start_engine())

car = Car()
moto = MotorCycle()

start_vehicle(car)
start_vehicle(moto)
# Out:
# Car engine started
# Motor cycle engine started
