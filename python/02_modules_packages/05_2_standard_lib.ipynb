# %%
# arrays

import array
arr = array.array('i', [1, 2, 3, 4])

print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
# maths library

import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
# random

import random
print(random.randint(1, 10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 9
# apple

# %%
# File and directory accessing

import os
print(os.getcwd())
# Out:
# c:\codes\python\02_modules_packages

# %%
os.mkdir('test_dir') #making directory of name test_dir
file = open('file.py', 'w')
file.close()

# %%
## High level operations on files and collection of files

import shutil
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization

import json

data = {
    'name': 'krish',
    'age': 19
}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "krish", "age": 19}
# <class 'str'>
# {'name': 'krish', 'age': 19}
# <class 'dict'>

# %%
## csv

import csv

with open('example.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['Krish', 32])

with open('example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['Krish', '32']

# %%
## datetime

from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now-timedelta(days=1)

print(yesterday)
# Out:
# 2025-12-29 21:10:59.320231
# 2025-12-28 21:10:59.320231

# %%
## time

import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1767022894.48059
# 1767022896.4826314

# %%
## regular expressions

import re

pattern = r'\d+'
text='There are 123 apples'
match = re.search(pattern, text)

print(match.group())
# Out:
# 123
